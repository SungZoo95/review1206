# %%
## 함수
def openBox() :
    print('상자를 엽니다~~')
    openBox()

# %%
## 메인 
openBox()
# Out:
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# 상자를 엽니다~~
# ...
