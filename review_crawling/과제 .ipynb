# %%
import pandas as pd
import requests

# %%
naver_mov = "https://movie.naver.com/movie/point/af/list.naver?&page=1"
naver_req = requests.get(naver_mov)
table_pd = pd.read_html(naver_req.text)

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[0]
# Out:
# '10'

# %%
# 방법1 한재처럼 if써서 합쳐보기
# 방법2 새로 컬럼 하나 만들고 df랑 컨캣 조져버리기

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[1]
# Out:
# '보는내내 시간이 어떻게 가는줄 모를정도로긴장감,재미,감동 등 너무 재미 있게 보았다'

# %%
for i in range(1, 10):
    naver_mov = f"https://movie.naver.com/movie/point/af/list.naver?&page={i}"
    naver_req = requests.get(naver_mov)
    table_pd = pd.read_html(naver_req.text)

# %%
table_pd[0]['감상평'][4].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[1]
# Out:
# '보는내내 시간이 어떻게 가는줄 모를정도로긴장감,재미,감동 등 너무 재미 있게 보았다'

# %%
df = pd.DataFrame(columns = ["번호", "제목", "감상평", "점수", "점수2"])
#df2 = pd.DataFrame(columns =["점수", "점수2"])

for i in range(1, 10):
    naver_mov = f"https://movie.naver.com/movie/point/af/list.naver?&page={i}"
    naver_req = requests.get(naver_mov)
    table_pd = pd.read_html(naver_req.text)
    
    for i in range(1, 8):
        movie_num = table_pd[0]['번호'][i]
        movie_title = table_pd[0]['감상평'][i].split(" 별점 - 총 10점 중")[0]
        movie_write = table_pd[0]['감상평'][i].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[1]
        star = table_pd[0]['감상평'][i].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[0]
        df =  df.append({"번호": int(movie_num), "제목": movie_title, "감상평": movie_write, "점수": star},  ignore_index=True)
       
        #df = pd.concat([df, df_2])
        #for j in range(2,10) : 
        #    #df.점수[j] = table_pd[0]["감상평"][i].split("  별점 - 총 10점 중")[1][:-3].split("  ")[0]
        #    if df.점수[j] >= 7:
        #        df.점수2[j] = 1
        #    else : 
        #        df.점수2[j] = 0
        #

# %%
table_pd[0]['감상평'][i].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[0]
# Out:
# '10'

# %%
df
# Out:
#           번호             제목  \
# 0   18596259     아바타: 물의 길
# 1   18596258     아바타: 물의 길
# 2   18596257     아바타: 물의 길
# 3   18596256     아바타: 물의 길
# 4   18596255     원피스 필름 레드
# ..       ...            ...
# 58  18596177     아바타: 물의 길
# 59  18596175            헌트
# 60  18596176     아바타: 물의 길
# 61  18596174            헌트
# 62  18596173  혐오스런 마츠코의 일생
#
#                                                   감상평  점수  점수2
# 0    최고의 시청각적 쾌감을 선사하는 영화! 스토리는 단순하지만 지루할 틈이 없었습니다~ㅎㅎ  10  NaN
# 1   오늘 2D로 보고 왔다. 3시간10여분의 긴 스토리..조금 지겹더라.대,소변 관리 ...   7  NaN
# 2                    남돌비에서 봤습니다. 현재 영상 기술의 정점을 보고왔네요.  10  NaN
# 3                               진짜 새로운 경험을 한듯꼭 3D를 추천  10  NaN
# 4                         샹크스로 인해 커진 기대를 우타가 채워주진 못했음   6  NaN
# ..                                                ...  ..  ...
# 58                                    개꿀잼 3번도 볼 저신 있음  10  NaN
# 59  한국영화를 한글자막 보면서 본 영화는 이게 처음. 배경소리나 음악때문에 대사가 안들...   6  NaN
# 60  1편이었으면 충격적이었지만 1편을 경험한 13년 뒤에 보는 기대감을 무너뜨리는 실망...   8  NaN
# 61  이정재 감독 내공이 느껴지네요혼돈스러운 심리에서 나오는 각각의 총질.. 광기어린 역...  10  NaN
# 62     슬프고 답답하고 바보같은 마츠코를 보며 왜 위로가 될까. 내 인생이 위로받는 기분.  10  NaN
#
# [63 rows x 5 columns]

# %%
movie_star
# Out:
# ['10', '너무 재밌음. 연말연화로 굿']

# %%
df_2 = pd.DataFrame(columns = ["점수2"])

for x in range(1, 5) :      
     
     if int(movie_star2) >= 7:
            df.점수2[x] = 1
     else : 
            df.점수2[x] = 0

# %%
df_2
# Out:
# Empty DataFrame
# Columns: [점수2]
# Index: []

# %%
movie_star[0]
# Out:
# '10'

# %%
table_pd[0]
# Out:
#          번호                                                감상평  \
# 0  18596204  아바타: 물의 길  별점 - 총 10점 중10  청주 성안길 cgv 대학생들 앞, ...
# 1  18596203       데시벨  별점 - 총 10점 중1  아이돌 나오면 영화 망한다는게 사실이네 신고
# 2  18596202  올빼미  별점 - 총 10점 중8  설정도 신선하고 재밌었지만 뭔가 기대보다는 영화...
# 3  18596201      아바타: 물의 길  별점 - 총 10점 중10  이건 정말 안보면 손해!!! 신고
# 4  18596200       아바타: 물의 길  별점 - 총 10점 중10  3시간이 휘리릭 지나가네요 신고
# 5  18596199       아바타: 물의 길  별점 - 총 10점 중10  3시간이 휘리릭 지나가네요 신고
# 6  18596198  아바타: 물의 길  별점 - 총 10점 중9  3시간동안 진짜 영상에 푹 빠져서 보...
# 7  18596197  아바타: 물의 길  별점 - 총 10점 중9  괜히 아바타 아바타 하는게 아니었네....
# 8  18596196  아바타: 물의 길  별점 - 총 10점 중10  대존잼.. 사냥꾼 새끼들 진짜 구어...
# 9  18596195      아바타: 물의 길  별점 - 총 10점 중10  너무 재밌음. 연말연화로 굿 신고
#
#               글쓴이·날짜
# 0  poiu**** 22.12.15
# 1  dheo**** 22.12.15
# 2  joon**** 22.12.15
# 3  voni**** 22.12.15
# 4  mini**** 22.12.15
# 5  mini**** 22.12.15
# 6  wltn**** 22.12.15
# 7  dbwn**** 22.12.15
# 8  grai**** 22.12.15
# 9  kh_j**** 22.12.15

# %%
df
# Out:
#          번호          제목                                                감상평  \
# 0  18596203        데시벨                               아이돌 나오면 영화 망한다는게 사실이네
# 1  18596202        올빼미   설정도 신선하고 재밌었지만 뭔가 기대보다는 영화 스케일이 좀 작다고 느꼈어요.. 영...
# 2  18596201  아바타: 물의 길                                     이건 정말 안보면 손해!!!
# 3  18596200  아바타: 물의 길                                      3시간이 휘리릭 지나가네요
# 4  18596199  아바타: 물의 길                                      3시간이 휘리릭 지나가네요
# 5  18596198  아바타: 물의 길   3시간동안 진짜 영상에 푹 빠져서 보았습니다. 1점 뺀 이유는 1편과 비교해서 약간...
# 6  18596197  아바타: 물의 길                               괜히 아바타 아바타 하는게 아니었네..
# 7  18596196  아바타: 물의 길   대존잼.. 사냥꾼 새끼들 진짜 구어체로 욕할뻔 다죽여버리고싶었음 진짜 나쁜놈들아!!...
# 8  18596195  아바타: 물의 길                                     너무 재밌음. 연말연화로 굿
#
#    점수  점수2
# 0   1  NaN
# 1   8  NaN
# 2  10  NaN
# 3  10  NaN
# 4  10  NaN
# 5   9  NaN
# 6   9  NaN
# 7  10  NaN
# 8  10  NaN

# %%
 if int(movie_star[i]) >= 7:
            df.점수2[i] = 1
        else : 
            df.점수2[i] = 0
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df.점수2[0]
#
# File /mnt/c/Users/student/Desktop/lab/webcrawling/lib/python3.10/site-packages/pandas/core/series.py:978, in Series.__getitem__(self, key)
#     975     key = unpack_1tuple(key)
#     977 if is_integer(key) and self.index._should_fallback_to_positional:
# --> 978     return self._values[key]
#     980 elif key_is_scalar:
#     981     return self._get_value(key)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
movie_num = table_pd[0]['번호']
movie_title = table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[0]
movie_write = table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[1]
movie_star = table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[0]

# %%
table_pd[0]
# Out:
#          번호                                                감상평
# 0  18595100  아바타: 물의 길  별점 - 총 10점 중10  흥행영화의 공식 같은 스토리를 따라...
# 1  18595099     아바타: 물의 길  별점 - 총 10점 중10  진짜 세시간이 훅가는영화입니다 신고
# 2  18595098  5 데이즈 오브 워  별점 - 총 10점 중10  픽션이나 드라마적인 연출이 많아서...
# 3  18595097  아바타: 물의 길  별점 - 총 10점 중5  아바타‘2’일뿐 뭉퉁해진 아바타‘1’ 신고
# 4  18595096       자백  별점 - 총 10점 중6  소지섭 나나 비주얼 제외하면 원작이 낫다 신고
# 5  18595095  아바타: 물의 길  별점 - 총 10점 중10  시간이 훅가버렸고ㅠ역시 아바타 너무...
# 6  18595094  아바타: 물의 길  별점 - 총 10점 중10  내가 마치 3시간동안 아바타가 된 ...
# 7  18595093               각설탕  별점 - 총 10점 중7  기본에 충실한 착한 영화 신고
# 8  18595092                      아바타: 물의 길  별점 - 총 10점 중10  신고
# 9  18595091  아바타: 물의 길  별점 - 총 10점 중10  난 엄청 재밌었음 그냥 보세요스토리...

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")
# Out:
# ['아바타: 물의 길 ',
#  '10  흥행영화의 공식 같은 스토리를 따라가지만 누구도 범접할수 없는 영상미와 인간이 자연을 대하는 마음가짐을 다시한번 생각하게 해주는 아름다운 영상과 속도감있는 액션은 관객의 시간을 훔쳐가기에는 충분하고도 남았다고 생각한다. 신고']

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[0]
# Out:
# '아바타: 물의 길 '

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")
# Out:
# ['10',
#  '흥행영화의 공식 같은 스토리를 따라가지만 누구도 범접할수 없는 영상미와 인간이 자연을 대하는 마음가짐을 다시한번 생각하게 해주는 아름다운 영상과 속도감있는 액션은 관객의 시간을 훔쳐가기에는 충분하고도 남았다고 생각한다.']

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[0]
# Out:
# '10'

# %%
table_pd[0]['감상평'][0].split(" 별점 - 총 10점 중")[1][:-3].split("  ")[1]
# Out:
# '흥행영화의 공식 같은 스토리를 따라가지만 누구도 범접할수 없는 영상미와 인간이 자연을 대하는 마음가짐을 다시한번 생각하게 해주는 아름다운 영상과 속도감있는 액션은 관객의 시간을 훔쳐가기에는 충분하고도 남았다고 생각한다.'

# %%
table_pd[0].drop(columns=['글쓴이·날짜'], inplace=True)

# %%
table_pd[0]
# Out:
#          번호                                                감상평
# 0  18595100  아바타: 물의 길  별점 - 총 10점 중10  흥행영화의 공식 같은 스토리를 따라...
# 1  18595099     아바타: 물의 길  별점 - 총 10점 중10  진짜 세시간이 훅가는영화입니다 신고
# 2  18595098  5 데이즈 오브 워  별점 - 총 10점 중10  픽션이나 드라마적인 연출이 많아서...
# 3  18595097  아바타: 물의 길  별점 - 총 10점 중5  아바타‘2’일뿐 뭉퉁해진 아바타‘1’ 신고
# 4  18595096       자백  별점 - 총 10점 중6  소지섭 나나 비주얼 제외하면 원작이 낫다 신고
# 5  18595095  아바타: 물의 길  별점 - 총 10점 중10  시간이 훅가버렸고ㅠ역시 아바타 너무...
# 6  18595094  아바타: 물의 길  별점 - 총 10점 중10  내가 마치 3시간동안 아바타가 된 ...
# 7  18595093               각설탕  별점 - 총 10점 중7  기본에 충실한 착한 영화 신고
# 8  18595092                      아바타: 물의 길  별점 - 총 10점 중10  신고
# 9  18595091  아바타: 물의 길  별점 - 총 10점 중10  난 엄청 재밌었음 그냥 보세요스토리...
